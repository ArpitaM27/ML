# %% [markdown]
# <a href="https://colab.research.google.com/github/ArpitaM27/ML/blob/main/02_python_var%26conditionals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("share your secret message ")
print(name)
# Out:
# share your secret message  U da boss
#  U da boss

# %%
#enter 2nos n find sum
a=int(input("enter 1st no "))
b=int(input("enter 2nd no "))
print("output is:",a+b)
# Out:
# enter 1st no 32
# enter 2nd no 889
# output is: 921

# %%
#enter side of square n print area
a=int(input("enter side of square "))
area= a*a
print("area of square is:",area)
# Out:
# enter side of square 4
# area of square is: 16

# %%
#input 2 nos n if ais greater than b return true
a=int(input("enter first no"))
b=int(input("enter 2nd no"))
print(a>=b)
# Out:
# enter first no99
# enter 2nd no32
# True
