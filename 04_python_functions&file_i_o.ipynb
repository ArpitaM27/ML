# %% [markdown]
# <a href="https://colab.research.google.com/github/ArpitaM27/ML/blob/main/04_python_functions%26file_i_o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Waf to print length of list
list=[]
index=0
while index<11:
 val=int(input("place your values "))
 list.append(val)
 index+=1
def length(x):
  return len(x)

length(list)
# Out:
# place your values 6
# place your values 7
# place your values 88
# place your values 99
# place your values 08
# place your values 7
# place your values 55
# place your values 6
# place your values 3
# place your values 3
# place your values 2
# 11
# 11

# %%
x = int(input("enter ur no "))

def fact(n):
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

print(fact(x))
# Out:
# enter ur no 7
# 5040

# %%
#take input n declare a function as odd or even
def find():
  n=int(input("enter ur no"))
  if(n%2==0):
    print("no is even")
  else:
    print("no is odd")

find()
# Out:
# enter ur no8
# no is even

# %%
#recursive function to print sum of n nos
def sum(n):
  if(n==0):
    return 0
  result=n+sum(n-1)
  return result
x=int(input("enter ur no "))
sum(x)
# Out:
# enter ur no6
# 21

# %%
#recursive functn to print all elements in a list
list=[2,3,4,5,6,66.78]
def functn(arr,index=0):
  if index == len(arr):   # base case
        return
    print(arr[index])

  functn(arr,index+1)

functn(list)
# Out:
#   File "<tokenize>", line 6
#     print(arr[index])
#     ^
# IndentationError: unindent does not match any outer indentation level
